# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/consistent_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id_order            brand  \
# 0           0    299539         Otterbox
# 1           1    299540               LG
# 2           2    299541           Parrot
# 3           3    299542  Western Digital
# 4           4    299543              JBL
#
#                                                 name  \
# 0  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...
# 1         27UD58-B LG Monitor 27 "4K UHD DisplayPort
# 2  Parrot Bebop 2 White + Command FLYPAD and FPV ...
# 3              Blue WD 2TB Hard Drive 35 "Mac and PC
# 4                      Gray Bluetooth Speaker JBL GO
#
#                                                 desc  total_paid  total_price  \
# 0  resistant cover and thin beveled edges for iPh...       18.99        18.99
# 1  Monitor for gamers and multimedia professional...      399.00       399.00
# 2  cuadricóptero wireless remote control with 25 ...      474.05       474.05
# ...
